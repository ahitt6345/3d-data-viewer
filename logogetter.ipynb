# %%
import os

# Create a directory to save the logos
if not os.path.exists('logos'):
    os.makedirs('logos')

# %%
# List of companies
companies = []

import csv

csv_file_path = 'Backend/newgendata.csv'

# Read the CSV file and extract company names
with open(csv_file_path, mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)  # Skip the header row
    for row in csv_reader:
        company_name = row[0]
        company_website = row[1]
        companies.append((company_name, company_website))

# Print the extracted company names (for verification)
for company in companies:
    print(company)

# Optionally, you can also use pandas to read the CSV file and extract the company names
import pandas as pd

# Read the CSV file
df = pd.read_csv(csv_file_path)

# Extract company names
companies_pandas = df['Companies'].tolist()

# Print the extracted company names (for verification)
for company in companies_pandas:
    print(company)
# Out:
# ('Grammarly', 'grammarly.com')
# ('Fractl', 'fractl.io')
# ('Debuild', 'debuild.co')
# ('Topline Pro', 'prophone.com')
# ('Pygma', 'pygma.app')
# ('Stack AI', 'stack-ai.com')
# ('Vellum', 'vellum.ai')
# ('Descript', 'descript.com')
# ('Podcastle', 'podcastle.ai')
# ('Murf AI', 'murf.ai')
# ('Lovo', 'lovo.ai')
# ('PlayHT', 'play.ht')
# ('Listnr', 'listnr.tech')
# ('Speechify', 'speechify.com')
# ('ElevenLabs', 'elevenlabs.io')
# ('WellSaid Labs', 'wellsaidlabs.com')
# ('Anecdote', 'anec.app')
# ('Enterpret', 'enterpret.com')
# ('Viable Fit', 'askviable.com')
# ('GoCharlie', 'gocharlie.ai')
# ('Osmosis', 'osmosis.studio')
# ('Omneky', 'omneky.com')
# ('Fliki', 'fliki.ai')
# ('Pictory', 'pictory.ai')
# ('Opus Clip', 'opus.pro')
# ('Pinecone', 'pinecone.io')
# ('Zilliz', 'zilliz.com')
# ('Chroma', 'trychroma.com')
# ('NNext', 'nnext.ai')
# ('Linq Labs', 'getlinq.com')
# ('Machinet', 'machinet.net')
# ('SapientAI', 'sapient.ai')
# ('Pika Art', 'pika.art')
# ('Formulabot', 'formulabot.com')
# ('Seek AI', 'seek.ai')
# ('AI2sql', 'ai2sql.io')
# ('SimplyPut', 'simplyput.ai')
# ('Ellipsis', 'ellipsis.dev')
# ('Magic Loops', 'magicloops.dev')
# ('Primer', 'primer.ai')
# ('plnia', 'plnia.com')
# ('Elicit', 'elicit.com')
# ('Synthesis AI', 'synthesis.ai')
# ('Parallel Domain', 'paralleldomain.com')
# ('Zumo Labs', 'zumolabs.ai')
# ('Chooch', 'chooch.com')
# ('Speedy', 'speedybrand.io')
# ('Pepper Content', 'peppercontent.io')
# ('Writesonic', 'writesonic.com')
# ('Linguix', 'linguix.com')
# ('Copy.AI', 'copy.ai')
# ('Jasper', 'jasper.ai')
# ('Anyword', 'anyword.com')
# ('Bertha', 'bertha.ai')
# ('Copyrytr', 'copyrytr.com')
# ('Mutiny', 'mutinyhq.com')
# ('Regie.ai', 'regie.ai')
# ('Cathie AI', 'cathie.ai')
# ('Writer', 'writer.com')
# ('Novus', 'novuswriter.ai')
# ('Copysmith', 'copysmith.ai')
# ('Typeface', 'typeface.ai')
# ('Persado', 'persado.com')
# ('Daydrm.ai', 'daydrm.ai')
# ('Contlo', 'contlo.com')
# ('PromptArmor', 'promptarmor.com')
# ('SlashNext', 'slashnext.com')
# ('Add Value Machine', 'addvaluemachine.com')
# ('Titaniam', 'titaniam.io')
# ('Preamble', 'preamble.com')
# ('Tofu', 'tofuhq.com')
# ('Magic Sales Bot', 'magicsalesbot.com')
# ('Lavender', 'lavender.ai')
# ('Outplay', 'outplayhq.com')
# ('Lyne.ai', 'lyne.ai')
# ('rule5 AI', 'rule5.io')
# ('Cquence', 'cquence.app')
# ('Clay', 'clay.com')
# ('DealPage', 'dealpage.ai')
# ('Vieu', 'try.vieu.com')
# ('Letter AI', 'letter.ai')
# ('Nous Research', 'nousresearch.com')
# ('Glean', 'glean.com')
# ('Dashworks', 'dashworks.ai')
# ('Assistive', 'assistive.chat')
# ('Brainbase', 'usebrainbase.xyz')
# ('Hebbia', 'hebbia.ai')
# ('Maya AI', 'meetmaya.world')
# ('Mem', 'mem.ai')
# ('Wild Moose', 'wildmoose.ai')
# ('Boundary', 'boundaryml.com')
# ('Got It AI', 'got-it.ai')
# ('Orby AI', 'orby.ai')
# ('Floworks', 'floworks.ai')
# ('Mano', 'usemano.com')
# ('Pano', 'pano.co')
# ('Rohirrim', 'rohirrim.ai')
# ('PairUp', 'pairupapp.com')
# ('Vianai Systems', 'vian.ai')
# ('OpenCopilot', 'opencopilot.so')
# ('Buster', 'buster.so')
# ('Lumina', 'lumina-chat.com')
# ('Upsolve', 'upsolve.ai')
# ('Danswer', 'danswer.ai')
# ('ZBrain', 'zbrain.ai')
# ('Swirl', 'swirl.today')
# ('Kay', 'kay.ai')
# ('Kinetica', 'kinetica.com')
# ('Kognitos', 'kognitos.com')
# ('Mantium', 'mantiumai.com')
# ('SkyPoint Cloud', 'skypointcloud.com')
# ('boodleAI', 'boodle.ai')
# ('Colibri', 'colibri.ai')
# ('Humaxa', 'humaxa.com')
# ('OneReach', 'onereach.ai')
# ('Nixtla', 'nixtla.io')
# ('alpaca', 'getalpaca.io')
# ("Let's Enhance", 'letsenhance.io')
# ('Runway', 'runwayml.com')
# ('Facet', 'facet.ai')
# ('Topaz Labs', 'topazlabs.com')
# ('Wonder Dynamics', 'wonderdynamics.com')
# ('Terra', 'welcometerra.com')
# ('Compose AI', 'compose.ai')
# ('HyperWrite', 'hyperwriteai.com')
# ('Sudowrite', 'sudowrite.com')
# ('Oasis', 'theoasis.com')
# ('Replika', 'replika.ai')
# ('Chai', 'chai-research.com')
# ('QuickChat', 'quickchat.io')
# ('Soundful', 'soundful.com')
# ('Mubert', 'mubert.com')
# ('Boomy', 'boomy.com')
# ('Aimi', 'aimi.fm')
# ('Plask', 'plask.ai')
# ('DeepMotion', 'deepmotion.com')
# ('RADiCAL', 'radicalmotion.com')
# ('Craiyon', 'craiyon.com')
# ('Midjourney', 'midjourney.com')
# ('OpenAI', 'openai.com')
# ('Contextual AI', 'contextual.ai')
# ('Together AI', 'together.ai')
# ('Databricks', 'databricks.com')
# ('xAI', 'x.ai')
# ('Runa AI', 'runaai.com')
# ('Lamini', 'lamini.ai')
# ('Baseplate', 'baseplate.ai')
# ('Qtis AI', 'qtis.ai')
# ('Scale', 'scale.com')
# ('Fiddler AI', 'fiddler.ai')
# ('Lightning AI', 'lightning.ai')
# ('WhyLabs', 'whylabs.ai')
# ('MosaicML', 'mosaicml.com')
# ('Snorkel AI', 'snorkel.ai')
# ('LangChain', 'langchain.com')
# ('Fixie', 'fixie.ai')
# ('MindsDB', 'mindsdb.com')
# ('Portkey', 'portkey.ai')
# ('D-Matrix', 'd-matrix.ai')
# ('Gentrace', 'gentrace.ai')
# ('Gretel', 'gretel.ai')
# ('DataRobot', 'datarobot.com')
# ('Domino', 'dominodatalab.com')
# ('Clarifai', 'clarifai.com')
# ('H2O.ai', 'h2o.ai')
# ('BentoML', 'bentoml.com')
# ('Continual', 'continual.ai')
# ('Arthur', 'arthur.ai')
# ('Kobalt Labs', 'kobaltlabs.com')
# ('Neural Magic', 'neuralmagic.com')
# ('Wallaroo', 'wallaroo.ai')
# ('Arize', 'arize.com')
# ('TruEra', 'truera.com')
# ('Robust Intelligence', 'robustintelligence.com')
# ('Aporia', 'aporia.com')
# ('Evidently AI', 'evidentlyai.com')
# ('Censius', 'censius.ai')
# ('OctoML', 'octoml.ai')
# ('Modzy', 'modzy.com')
# ('Credo AI', 'credo.ai')
# ('MAIHEM', 'maihem.ai')
# ('Reducto AI', 'reducto.ai')
# ('Glaive', 'glaive.ai')
# ('Arcee', 'arcee.ai')
# ('Martian', 'withmartian.com')
# ('Cleanlab', 'cleanlab.ai')
# ('Automorphic', 'automorphic.ai')
# ('Taylor AI', 'trytaylor.ai')
# ('Deasie', 'deasie.com')
# ('LlamaIndex', 'llamaindex.ai')
# ('Talc', 'talc.ai')
# ('FiddleCube', 'fiddlecube.ai')
# ('Patronus AI', 'patronus.ai')
# ('DeepInfra', 'deepinfra.com')
# ('SID', 'sid.ai')
# ('VectorShift', 'vectorshift.ai')
# ('Unstructured', 'unstructured.io')
# ('Chatter', 'trychatter.ai')
# ('TextQL', 'textql.com')
# ('PromptLoop', 'promptloop.com')
# ('Baserun', 'baserun.ai')
# ('DAGWorks', 'dagworks.io')
# ('Panosight', 'panosight.ai')
# ('Vecflow', 'vecflow.ai')
# ('Guardrail ML', 'useguardrail.com')
# ('Confident AI', 'confident-ai.com')
# ('Hegel AI', 'hegel-ai.com')
# ('HydroX AI', 'hydrox.ai')
# ('Konko AI', 'konko.ai')
# ('Athina AI', 'athina.ai')
# ('Lega', 'lega.ai')
# ('Kore.ai', 'kore.ai')
# ('Abacus.AI', 'abacus.ai')
# ('Aible', 'aible.com')
# ('Numbers Station', 'numbersstation.ai')
# ('DataCebo', 'datacebo.com')
# ('Watchful', 'watchful.io')
# ('RagaAI', 'raga.ai')
# ('dottxt', 'dottxt.co')
# ('TieSet', 'tie-set.com')
# ('Trustwise', 'trustwise.ai')
# ('Monster API', 'monsterapi.ai')
# ('Carbon', 'carbon.ai')
# ('OpenPipe', 'openpipe.ai')
# ('Query Vary', 'queryvary.com')
# ('Shorthills AI', 'shorthills.ai')
# ('GradientJ', 'gradientj.com')
# ('Forefront', 'forefront.ai')
# ('Replicate', 'replicate.com')
# ('Calypso AI', 'calypsoai.com')
# ('HiddenLayer', 'hiddenlayer.com')
# ('Klleon', 'klleon.io')
# ('Tavus', 'tavus.io')
# ('Beam', 'beam.so')
# ('Nyx.gallery', 'nyx.gallery')
# ('mage.space', 'mage.space')
# ('OpenArt', 'openart.ai')
# ('Lexica', 'lexica.art')
# ('Booth AI', 'booth.ai')
# ('Hyperreal', 'hyperreal.io')
# ('Apriora', 'apriora.ai')
# ('Our Ability', 'ourability.com')
# ('Vizcom', 'vizcom.ai')
# ('Aragon', 'aragon.ai')
# ('Mirage', 'mirageml.com')
# ('Poly', 'withpoly.com')
# ('Diagram', 'withdiagram.com')
# ('Etched', 'etched.ai')
# ('Lumona', 'lumona.ai')
# ('Perplexity AI', 'perplexity.ai')
# ('Andi', 'andisearch.com')
# ('Vectara', 'vectara.com')
# ('Twelve Labs', 'twelvelabs.io')
# ('You.com', 'you.com')
# ('Neeva', 'neeva.com')
# ('Exa', 'exa.ai')
# ('EleutherAI', 'eleuther.ai')
# ('Pinscreen', 'pinscreen.com')
# ('HeyGen', 'heygen.com')
# ('UneeQ', 'digitalhumans.com')
# ('The AI Foundation', 'aifoundation.com')
# ('Rephrase.ai', 'rephrase.ai')
# ('D-ID', 'd-id.com')
# ('Pulze.ai', 'pulze.ai')
# ('Sublayer', 'sublayer.com')
# ('NuMind', 'numind.ai')
# ('Flip AI', 'flip.ai')
# ('Leo AI', 'getleo.ai')
# ('Autoblocks', 'autoblocks.ai')
# ('Galileo AI', 'usegalileo.ai')
# ('Nexusflow', 'nexusflow.ai')
# ('Jericho Security', 'jerichosecurity.com')
# ('Shiboleth', 'shiboleth.ai')
# ('Wraithwatch', 'wraithwatch.com')
# ('System Two Security', 'systemtwosecurity.com')
# ('Cape Privacy', 'capeprivacy.com')
# ('Reken', 'reken.ai')
# ('Sec3', 'sec3.dev')
# ('Inkeep AI', 'inkeep.com')
# ('Uniphore', 'uniphore.com')
# ('Forethought', 'forethought.ai')
# ('Sapling Intelligence', 'sapling.ai')
# ('Verneek', 'verneek.com')
# ('Quickchat AI', 'quickchat.ai')
# ('Thankful', 'thankful.ai')
# ('NLX', 'nlx.ai')
# ('Gleen', 'gleen.ai')
# ('Markprompt', 'markprompt.com')
# ('Toma', 'toma.so')
# ('Centralize', 'usecentralize.com')
# ('HiOperator', 'hioperator.com')
# ('Alltius', 'alltius.ai')
# ('VAO Labs', 'vao.world')
# ('Monterey', 'monterey.ai')
# ('Humane', 'humane.com')
# ('Rewind', 'rewind.ai')
# ('Tab', 'mytab.ai')
# ('rabbit', 'rabbit.tech')
# ('Reface', 'hey.reface.ai')
# ('Maia', 'ourmaia.com')
# ('Alai', 'getalai.com')
# ('Personal AI', 'personal.ai')
# ('Earkick', 'earkick.com')
# ('Warp', 'warp.dev')
# ('Fig', 'fig.io')
# ('Cosine', 'cosine.sh')
# ('Mintlify', 'mintlify.com')
# ('Denigma Alpha', 'denigma.app')
# ('Replit', 'replit.com')
# ('MutableAI', 'mutable.ai')
# ('CodeComplete', 'codecomplete.ai')
# ('Second', 'second.dev')
# ('Codiga', 'codiga.io')
# ('Kite', 'kite.com')
# ('Deepgram', 'deepgram.com')
# ('Symbl.ai', 'symbl.ai')
# ('AssemblyAI', 'assemblyai.com')
# ('Cogram', 'cogram.com')
# ('Talka', 'talka.ai')
# ('Vocal Clarity', 'vocalclarity.ai')
# ('Griptape', 'griptape.ai')
# ('Imbue', 'imbue.com')
# ('Inflection', 'inflection.ai')
# ('Character.AI', 'beta.character.ai')
# ('Digi', 'digi.ai')
# ('Anthropic', 'anthropic.com')
# ('Adept', 'adept.ai')
# ('Superagent', 'superagent.sh')
# Grammarly
# Fractl
# Debuild
# Topline Pro
# Pygma
# Stack AI
# Vellum
# Descript
# Podcastle
# Murf AI
# Lovo
# PlayHT
# Listnr
# Speechify
# ElevenLabs
# WellSaid Labs
# Anecdote
# Enterpret
# Viable Fit
# GoCharlie
# Osmosis
# Omneky
# Fliki
# Pictory
# Opus Clip
# Pinecone
# Zilliz
# Chroma
# NNext
# Linq Labs
# Machinet
# SapientAI
# Pika Art
# Formulabot
# Seek AI
# AI2sql
# SimplyPut
# Ellipsis
# Magic Loops
# Primer
# plnia
# Elicit
# Synthesis AI
# Parallel Domain
# Zumo Labs
# Chooch
# Speedy
# Pepper Content
# Writesonic
# Linguix
# Copy.AI
# Jasper
# Anyword
# Bertha
# Copyrytr
# Mutiny
# Regie.ai
# Cathie AI
# Writer
# Novus
# Copysmith
# Typeface
# Persado
# Daydrm.ai
# Contlo
# PromptArmor
# SlashNext
# Add Value Machine
# Titaniam
# Preamble
# Tofu
# Magic Sales Bot
# Lavender
# Outplay
# Lyne.ai
# rule5 AI
# Cquence
# Clay
# DealPage
# Vieu
# Letter AI
# Nous Research
# Glean
# Dashworks
# Assistive
# Brainbase
# Hebbia
# Maya AI
# Mem
# Wild Moose
# Boundary
# Got It AI
# Orby AI
# Floworks
# Mano
# Pano
# Rohirrim
# PairUp
# Vianai Systems
# OpenCopilot
# Buster
# Lumina
# Upsolve
# Danswer
# ZBrain
# Swirl
# Kay
# Kinetica
# Kognitos
# Mantium
# SkyPoint Cloud
# boodleAI
# Colibri
# Humaxa
# OneReach
# Nixtla
# alpaca
# Let's Enhance
# Runway
# Facet
# Topaz Labs
# Wonder Dynamics
# Terra
# Compose AI
# HyperWrite
# Sudowrite
# Oasis
# Replika
# Chai
# QuickChat
# Soundful
# Mubert
# Boomy
# Aimi
# Plask
# DeepMotion
# RADiCAL
# Craiyon
# Midjourney
# OpenAI
# Contextual AI
# Together AI
# Databricks
# xAI
# Runa AI
# Lamini
# Baseplate
# Qtis AI
# Scale
# Fiddler AI
# Lightning AI
# WhyLabs
# MosaicML
# Snorkel AI
# LangChain
# Fixie
# MindsDB
# Portkey
# D-Matrix
# Gentrace
# Gretel
# DataRobot
# Domino
# Clarifai
# H2O.ai
# BentoML
# Continual
# Arthur
# Kobalt Labs
# Neural Magic
# Wallaroo
# Arize
# TruEra
# Robust Intelligence
# Aporia
# Evidently AI
# Censius
# OctoML
# Modzy
# Credo AI
# MAIHEM
# Reducto AI
# Glaive
# Arcee
# Martian
# Cleanlab
# Automorphic
# Taylor AI
# Deasie
# LlamaIndex
# Talc
# FiddleCube
# Patronus AI
# DeepInfra
# SID
# VectorShift
# Unstructured
# Chatter
# TextQL
# PromptLoop
# Baserun
# DAGWorks
# Panosight
# Vecflow
# Guardrail ML
# Confident AI
# Hegel AI
# HydroX AI
# Konko AI
# Athina AI
# Lega
# Kore.ai
# Abacus.AI
# Aible
# Numbers Station
# DataCebo
# Watchful
# RagaAI
# dottxt
# TieSet
# Trustwise
# Monster API
# Carbon
# OpenPipe
# Query Vary
# Shorthills AI
# GradientJ
# Forefront
# Replicate
# Calypso AI
# HiddenLayer
# Klleon
# Tavus
# Beam
# Nyx.gallery
# mage.space
# OpenArt
# Lexica
# Booth AI
# Hyperreal
# Apriora
# Our Ability
# Vizcom
# Aragon
# Mirage
# Poly
# Diagram
# Etched
# Lumona
# Perplexity AI
# Andi
# Vectara
# Twelve Labs
# You.com
# Neeva
# Exa
# EleutherAI
# Pinscreen
# HeyGen
# UneeQ
# The AI Foundation
# Rephrase.ai
# D-ID
# Pulze.ai
# Sublayer
# NuMind
# Flip AI
# Leo AI
# Autoblocks
# Galileo AI
# Nexusflow
# Jericho Security
# Shiboleth
# Wraithwatch
# System Two Security
# Cape Privacy
# Reken
# Sec3
# Inkeep AI
# Uniphore
# Forethought
# Sapling Intelligence
# Verneek
# Quickchat AI
# Thankful
# NLX
# Gleen
# Markprompt
# Toma
# Centralize
# HiOperator
# Alltius
# VAO Labs
# Monterey
# Humane
# Rewind
# Tab
# rabbit
# Reface
# Maia
# Alai
# Personal AI
# Earkick
# Warp
# Fig
# Cosine
# Mintlify
# Denigma Alpha
# Replit
# MutableAI
# CodeComplete
# Second
# Codiga
# Kite
# Deepgram
# Symbl.ai
# AssemblyAI
# Cogram
# Talka
# Vocal Clarity
# Griptape
# Imbue
# Inflection
# Character.AI
# Digi
# Anthropic
# Adept
# Superagent

# %%
import requests
# Function to get logo URL from Clearbit API
def get_logo_url(domain):
    api_url = f"https://logo.clearbit.com/{domain}"
    return api_url

# Function to download and save the logo
def download_logo(url, company_name):
    response = requests.get(url)
    if response.status_code == 200:
        file_path = os.path.join("logos", f"{company_name}.png")
        with open(file_path, "wb") as file:
            file.write(response.content)
        print(f"Downloaded logo for {company_name}")
    else:
        print(f"Could not find logo for {company_name}")

# Main loop to process each company
for company_name, company_url in companies:
    # if logo already exists, skip
    if os.path.exists(f"logos/{company_name}.png"):
        print(f"Logo for {company_name} already exists. Skipping...")
        continue
    logo_url = get_logo_url(company_url)
    response = requests.get(logo_url)
    if response.status_code == 200:
        download_logo(logo_url, company_name)
    else:
        print(f"No logo found for {company_name}")

print("Finished downloading logos.")
# Out:
# Logo for Grammarly already exists. Skipping...
# Logo for Fractl already exists. Skipping...
# Logo for Debuild already exists. Skipping...
# Logo for Topline Pro already exists. Skipping...
# Logo for Pygma already exists. Skipping...
# Logo for Stack AI already exists. Skipping...
# Logo for Vellum already exists. Skipping...
# Logo for Descript already exists. Skipping...
# Logo for Podcastle already exists. Skipping...
# Logo for Murf AI already exists. Skipping...
# Logo for Lovo already exists. Skipping...
# Logo for PlayHT already exists. Skipping...
# Logo for Listnr already exists. Skipping...
# Logo for Speechify already exists. Skipping...
# Logo for ElevenLabs already exists. Skipping...
# Logo for WellSaid Labs already exists. Skipping...
# Logo for Anecdote already exists. Skipping...
# Logo for Enterpret already exists. Skipping...
# Logo for Viable Fit already exists. Skipping...
# Logo for GoCharlie already exists. Skipping...
# Logo for Osmosis already exists. Skipping...
# Logo for Omneky already exists. Skipping...
# Logo for Fliki already exists. Skipping...
# Logo for Pictory already exists. Skipping...
# Logo for Opus Clip already exists. Skipping...
# Logo for Pinecone already exists. Skipping...
# Logo for Zilliz already exists. Skipping...
# Logo for Chroma already exists. Skipping...
# Logo for NNext already exists. Skipping...
# Logo for Linq Labs already exists. Skipping...
# Logo for Machinet already exists. Skipping...
# Logo for SapientAI already exists. Skipping...
# Logo for Pika Art already exists. Skipping...
# Logo for Formulabot already exists. Skipping...
# Logo for Seek AI already exists. Skipping...
# Logo for AI2sql already exists. Skipping...
# Logo for SimplyPut already exists. Skipping...
# Logo for Ellipsis already exists. Skipping...
# Logo for Magic Loops already exists. Skipping...
# Logo for Primer already exists. Skipping...
# Logo for plnia already exists. Skipping...
# Logo for Elicit already exists. Skipping...
# Logo for Synthesis AI already exists. Skipping...
# Logo for Parallel Domain already exists. Skipping...
# Logo for Zumo Labs already exists. Skipping...
# Logo for Chooch already exists. Skipping...
# Logo for Speedy already exists. Skipping...
# Logo for Pepper Content already exists. Skipping...
# Logo for Writesonic already exists. Skipping...
# Logo for Linguix already exists. Skipping...
# Logo for Copy.AI already exists. Skipping...
# Logo for Jasper already exists. Skipping...
# Logo for Anyword already exists. Skipping...
# Logo for Bertha already exists. Skipping...
# Logo for Copyrytr already exists. Skipping...
# Logo for Mutiny already exists. Skipping...
# Logo for Regie.ai already exists. Skipping...
# No logo found for Cathie AI
# Logo for Writer already exists. Skipping...
# Logo for Novus already exists. Skipping...
# Logo for Copysmith already exists. Skipping...
# Logo for Typeface already exists. Skipping...
# Logo for Persado already exists. Skipping...
# Logo for Daydrm.ai already exists. Skipping...
# Logo for Contlo already exists. Skipping...
# Logo for PromptArmor already exists. Skipping...
# Logo for SlashNext already exists. Skipping...
# Logo for Add Value Machine already exists. Skipping...
# Logo for Titaniam already exists. Skipping...
# Logo for Preamble already exists. Skipping...
# Logo for Tofu already exists. Skipping...
# Downloaded logo for Magic Sales Bot
# Logo for Lavender already exists. Skipping...
# Logo for Outplay already exists. Skipping...
# Logo for Lyne.ai already exists. Skipping...
# Logo for rule5 AI already exists. Skipping...
# Logo for Cquence already exists. Skipping...
# Logo for Clay already exists. Skipping...
# Logo for DealPage already exists. Skipping...
# Logo for Vieu already exists. Skipping...
# Logo for Letter AI already exists. Skipping...
# Logo for Nous Research already exists. Skipping...
# Logo for Glean already exists. Skipping...
# Logo for Dashworks already exists. Skipping...
# Logo for Assistive already exists. Skipping...
# Logo for Brainbase already exists. Skipping...
# Logo for Hebbia already exists. Skipping...
# Logo for Maya AI already exists. Skipping...
# Logo for Mem already exists. Skipping...
# Logo for Wild Moose already exists. Skipping...
# Logo for Boundary already exists. Skipping...
# Logo for Got It AI already exists. Skipping...
# Logo for Orby AI already exists. Skipping...
# Logo for Floworks already exists. Skipping...
# Logo for Mano already exists. Skipping...
# Logo for Pano already exists. Skipping...
# Logo for Rohirrim already exists. Skipping...
# Logo for PairUp already exists. Skipping...
# Logo for Vianai Systems already exists. Skipping...
# No logo found for OpenCopilot
# Logo for Buster already exists. Skipping...
# Logo for Lumina already exists. Skipping...
# No logo found for Upsolve
# No logo found for Danswer
# Downloaded logo for ZBrain
# Logo for Swirl already exists. Skipping...
# Logo for Kay already exists. Skipping...
# Logo for Kinetica already exists. Skipping...
# Logo for Kognitos already exists. Skipping...
# Downloaded logo for Mantium
# Downloaded logo for SkyPoint Cloud
# Downloaded logo for boodleAI
# Logo for Colibri already exists. Skipping...
# Logo for Humaxa already exists. Skipping...
# Logo for OneReach already exists. Skipping...
# Downloaded logo for Nixtla
# Logo for alpaca already exists. Skipping...
# Downloaded logo for Let's Enhance
# Logo for Runway already exists. Skipping...
# Logo for Facet already exists. Skipping...
# Downloaded logo for Topaz Labs
# Downloaded logo for Wonder Dynamics
# Logo for Terra already exists. Skipping...
# Downloaded logo for Compose AI
# Downloaded logo for HyperWrite
# Logo for Sudowrite already exists. Skipping...
# Logo for Oasis already exists. Skipping...
# Logo for Replika already exists. Skipping...
# Logo for Chai already exists. Skipping...
# Downloaded logo for QuickChat
# Logo for Soundful already exists. Skipping...
# Logo for Mubert already exists. Skipping...
# Logo for Boomy already exists. Skipping...
# Downloaded logo for Aimi
# Downloaded logo for Plask
# Logo for DeepMotion already exists. Skipping...
# Logo for RADiCAL already exists. Skipping...
# Logo for Craiyon already exists. Skipping...
# Logo for Midjourney already exists. Skipping...
# Logo for OpenAI already exists. Skipping...
# Downloaded logo for Contextual AI
# Downloaded logo for Together AI
# Logo for Databricks already exists. Skipping...
# No logo found for xAI
# Downloaded logo for Runa AI
# No logo found for Lamini
# Downloaded logo for Baseplate
# Downloaded logo for Qtis AI
# Logo for Scale already exists. Skipping...
# Downloaded logo for Fiddler AI
# Downloaded logo for Lightning AI
# Downloaded logo for WhyLabs
# Logo for MosaicML already exists. Skipping...
# Downloaded logo for Snorkel AI
# No logo found for LangChain
# Logo for Fixie already exists. Skipping...
# Logo for MindsDB already exists. Skipping...
# Logo for Portkey already exists. Skipping...
# Downloaded logo for D-Matrix
# Logo for Gentrace already exists. Skipping...
# Downloaded logo for Gretel
# Logo for DataRobot already exists. Skipping...
# Logo for Domino already exists. Skipping...
# Logo for Clarifai already exists. Skipping...
# Downloaded logo for H2O.ai
# Logo for BentoML already exists. Skipping...
# Downloaded logo for Continual
# Downloaded logo for Arthur
# No logo found for Kobalt Labs
# Downloaded logo for Neural Magic
# Logo for Wallaroo already exists. Skipping...
# Logo for Arize already exists. Skipping...
# Logo for TruEra already exists. Skipping...
# Downloaded logo for Robust Intelligence
# Logo for Aporia already exists. Skipping...
# Downloaded logo for Evidently AI
# Logo for Censius already exists. Skipping...
# Logo for OctoML already exists. Skipping...
# Logo for Modzy already exists. Skipping...
# Downloaded logo for Credo AI
# No logo found for MAIHEM
# No logo found for Reducto AI
# No logo found for Glaive
# Logo for Arcee already exists. Skipping...
# No logo found for Martian
# Downloaded logo for Cleanlab
# No logo found for Automorphic
# No logo found for Taylor AI
# No logo found for Deasie
# No logo found for LlamaIndex
# Logo for Talc already exists. Skipping...
# Downloaded logo for FiddleCube
# Downloaded logo for Patronus AI
# Logo for DeepInfra already exists. Skipping...
# Logo for SID already exists. Skipping...
# No logo found for VectorShift
# Downloaded logo for Unstructured
# Logo for Chatter already exists. Skipping...
# Logo for TextQL already exists. Skipping...
# Logo for PromptLoop already exists. Skipping...
# No logo found for Baserun
# Downloaded logo for DAGWorks
# Downloaded logo for Panosight
# No logo found for Vecflow
# No logo found for Guardrail ML
# No logo found for Confident AI
# No logo found for Hegel AI
# No logo found for HydroX AI
# No logo found for Konko AI
# No logo found for Athina AI
# Logo for Lega already exists. Skipping...
# Downloaded logo for Kore.ai
# Downloaded logo for Abacus.AI
# Logo for Aible already exists. Skipping...
# Downloaded logo for Numbers Station
# Logo for DataCebo already exists. Skipping...
# Downloaded logo for Watchful
# Downloaded logo for RagaAI
# No logo found for dottxt
# Logo for TieSet already exists. Skipping...
# Downloaded logo for Trustwise
# No logo found for Monster API
# Logo for Carbon already exists. Skipping...
# No logo found for OpenPipe
# No logo found for Query Vary
# Downloaded logo for Shorthills AI
# Logo for GradientJ already exists. Skipping...
# Downloaded logo for Forefront
# Logo for Replicate already exists. Skipping...
# Downloaded logo for Calypso AI
# Logo for HiddenLayer already exists. Skipping...
# Downloaded logo for Klleon
# Downloaded logo for Tavus
# Logo for Beam already exists. Skipping...
# Logo for Nyx.gallery already exists. Skipping...
# Logo for mage.space already exists. Skipping...
# Logo for OpenArt already exists. Skipping...
# Downloaded logo for Lexica
# Downloaded logo for Booth AI
# Downloaded logo for Hyperreal
# No logo found for Apriora
# Downloaded logo for Our Ability
# Logo for Vizcom already exists. Skipping...
# Logo for Aragon already exists. Skipping...
# Logo for Mirage already exists. Skipping...
# Logo for Poly already exists. Skipping...
# No logo found for Diagram
# Logo for Etched already exists. Skipping...
# No logo found for Lumona
# Downloaded logo for Perplexity AI
# Logo for Andi already exists. Skipping...
# Logo for Vectara already exists. Skipping...
# Downloaded logo for Twelve Labs
# Logo for You.com already exists. Skipping...
# Logo for Neeva already exists. Skipping...
# Logo for Exa already exists. Skipping...
# Downloaded logo for EleutherAI
# Logo for Pinscreen already exists. Skipping...
# Logo for HeyGen already exists. Skipping...
# Logo for UneeQ already exists. Skipping...
# Downloaded logo for The AI Foundation
# Downloaded logo for Rephrase.ai
# Logo for D-ID already exists. Skipping...
# No logo found for Pulze.ai
# Logo for Sublayer already exists. Skipping...
# Downloaded logo for NuMind
# Downloaded logo for Flip AI
# No logo found for Leo AI
# Logo for Autoblocks already exists. Skipping...
# Downloaded logo for Galileo AI
# No logo found for Nexusflow
# No logo found for Jericho Security
# Logo for Shiboleth already exists. Skipping...
# No logo found for Wraithwatch
# No logo found for System Two Security
# Downloaded logo for Cape Privacy
# No logo found for Reken
# Downloaded logo for Sec3
# Downloaded logo for Inkeep AI
# Logo for Uniphore already exists. Skipping...
# Logo for Forethought already exists. Skipping...
# Downloaded logo for Sapling Intelligence
# Logo for Verneek already exists. Skipping...
# Downloaded logo for Quickchat AI
# Downloaded logo for Thankful
# Logo for NLX already exists. Skipping...
# Logo for Gleen already exists. Skipping...
# Logo for Markprompt already exists. Skipping...
# Logo for Toma already exists. Skipping...
# No logo found for Centralize
# Logo for HiOperator already exists. Skipping...
# Downloaded logo for Alltius
# Downloaded logo for VAO Labs
# Downloaded logo for Monterey
# Logo for Humane already exists. Skipping...
# Logo for Rewind already exists. Skipping...
# Logo for Tab already exists. Skipping...
# Logo for rabbit already exists. Skipping...
# Logo for Reface already exists. Skipping...
# Downloaded logo for Maia
# No logo found for Alai
# Downloaded logo for Personal AI
# Logo for Earkick already exists. Skipping...
# Downloaded logo for Warp
# Logo for Fig already exists. Skipping...
# Logo for Cosine already exists. Skipping...
# Logo for Mintlify already exists. Skipping...
# Downloaded logo for Denigma Alpha
# Logo for Replit already exists. Skipping...
# Logo for MutableAI already exists. Skipping...
# Downloaded logo for CodeComplete
# Downloaded logo for Second
# Downloaded logo for Codiga
# Logo for Kite already exists. Skipping...
# Logo for Deepgram already exists. Skipping...
# Downloaded logo for Symbl.ai
# Logo for AssemblyAI already exists. Skipping...
# Logo for Cogram already exists. Skipping...
# Logo for Talka already exists. Skipping...
# Downloaded logo for Vocal Clarity
# Logo for Griptape already exists. Skipping...
# No logo found for Imbue
# Logo for Inflection already exists. Skipping...
# Downloaded logo for Character.AI
# Logo for Digi already exists. Skipping...
# Logo for Anthropic already exists. Skipping...
# Logo for Adept already exists. Skipping...
# Logo for Superagent already exists. Skipping...
# Finished downloading logos.

# %%
#print a list of the companies we could not find logos for
companies_without_logos = [company_name for company_name, _ in companies if not os.path.exists(f"logos/{company_name}.png")]
print("Companies without logos:")
for company in companies_without_logos:
    print(company)
# Out:
# Companies without logos:
# ('Grammarly', 'grammarly.com')
# ('Fractl', 'fractl.io')
# ('Debuild', 'debuild.co')
# ('Topline Pro', 'prophone.com')
# ('Pygma', 'pygma.app')
# ('Stack AI', 'stack-ai.com')
# ('Vellum', 'vellum.ai')
# ('Descript', 'descript.com')
# ('Podcastle', 'podcastle.ai')
# ('Murf AI', 'murf.ai')
# ('Lovo', 'lovo.ai')
# ('PlayHT', 'play.ht')
# ('Listnr', 'listnr.tech')
# ('Speechify', 'speechify.com')
# ('ElevenLabs', 'elevenlabs.io')
# ('WellSaid Labs', 'wellsaidlabs.com')
# ('Anecdote', 'anec.app')
# ('Enterpret', 'enterpret.com')
# ('Viable Fit', 'askviable.com')
# ('GoCharlie', 'gocharlie.ai')
# ('Osmosis', 'osmosis.studio')
# ('Omneky', 'omneky.com')
# ('Fliki', 'fliki.ai')
# ('Pictory', 'pictory.ai')
# ('Opus Clip', 'opus.pro')
# ('Pinecone', 'pinecone.io')
# ('Zilliz', 'zilliz.com')
# ('Chroma', 'trychroma.com')
# ('NNext', 'nnext.ai')
# ('Linq Labs', 'getlinq.com')
# ('Machinet', 'machinet.net')
# ('SapientAI', 'sapient.ai')
# ('Pika Art', 'pika.art')
# ('Formulabot', 'formulabot.com')
# ('Seek AI', 'seek.ai')
# ('AI2sql', 'ai2sql.io')
# ('SimplyPut', 'simplyput.ai')
# ('Ellipsis', 'ellipsis.dev')
# ('Magic Loops', 'magicloops.dev')
# ('Primer', 'primer.ai')
# ('plnia', 'plnia.com')
# ('Elicit', 'elicit.com')
# ('Synthesis AI', 'synthesis.ai')
# ('Parallel Domain', 'paralleldomain.com')
# ('Zumo Labs', 'zumolabs.ai')
# ('Chooch', 'chooch.com')
# ('Speedy', 'speedybrand.io')
# ('Pepper Content', 'peppercontent.io')
# ('Writesonic', 'writesonic.com')
# ('Linguix', 'linguix.com')
# ('Copy.AI', 'copy.ai')
# ('Jasper', 'jasper.ai')
# ('Anyword', 'anyword.com')
# ('Bertha', 'bertha.ai')
# ('Copyrytr', 'copyrytr.com')
# ('Mutiny', 'mutinyhq.com')
# ('Regie.ai', 'regie.ai')
# ('Cathie AI', 'cathie.ai')
# ('Writer', 'writer.com')
# ('Novus', 'novuswriter.ai')
# ('Copysmith', 'copysmith.ai')
# ('Typeface', 'typeface.ai')
# ('Persado', 'persado.com')
# ('Daydrm.ai', 'daydrm.ai')
# ('Contlo', 'contlo.com')
# ('PromptArmor', 'promptarmor.com')
# ('SlashNext', 'slashnext.com')
# ('Add Value Machine', 'addvaluemachine.com')
# ('Titaniam', 'titaniam.io')
# ('Preamble', 'preamble.com')
# ('Tofu', 'tofuhq.com')
# ('Magic Sales Bot', 'magicsalesbot.com')
# ('Lavender', 'lavender.ai')
# ('Outplay', 'outplayhq.com')
# ('Lyne.ai', 'lyne.ai')
# ('rule5 AI', 'rule5.io')
# ('Cquence', 'cquence.app')
# ('Clay', 'clay.com')
# ('DealPage', 'dealpage.ai')
# ('Vieu', 'try.vieu.com')
# ('Letter AI', 'letter.ai')
# ('Nous Research', 'nousresearch.com')
# ('Glean', 'glean.com')
# ('Dashworks', 'dashworks.ai')
# ('Assistive', 'assistive.chat')
# ('Brainbase', 'usebrainbase.xyz')
# ('Hebbia', 'hebbia.ai')
# ('Maya AI', 'meetmaya.world')
# ('Mem', 'mem.ai')
# ('Wild Moose', 'wildmoose.ai')
# ('Boundary', 'boundaryml.com')
# ('Got It AI', 'got-it.ai')
# ('Orby AI', 'orby.ai')
# ('Floworks', 'floworks.ai')
# ('Mano', 'usemano.com')
# ('Pano', 'pano.co')
# ('Rohirrim', 'rohirrim.ai')
# ('PairUp', 'pairupapp.com')
# ('Vianai Systems', 'vian.ai')
# ('OpenCopilot', 'opencopilot.so')
# ('Buster', 'buster.so')
# ('Lumina', 'lumina-chat.com')
# ('Upsolve', 'upsolve.ai')
# ('Danswer', 'danswer.ai')
# ('ZBrain', 'zbrain.ai')
# ('Swirl', 'swirl.today')
# ('Kay', 'kay.ai')
# ('Kinetica', 'kinetica.com')
# ('Kognitos', 'kognitos.com')
# ('Mantium', 'mantiumai.com')
# ('SkyPoint Cloud', 'skypointcloud.com')
# ('boodleAI', 'boodle.ai')
# ('Colibri', 'colibri.ai')
# ('Humaxa', 'humaxa.com')
# ('OneReach', 'onereach.ai')
# ('Nixtla', 'nixtla.io')
# ('alpaca', 'getalpaca.io')
# ("Let's Enhance", 'letsenhance.io')
# ('Runway', 'runwayml.com')
# ('Facet', 'facet.ai')
# ('Topaz Labs', 'topazlabs.com')
# ('Wonder Dynamics', 'wonderdynamics.com')
# ('Terra', 'welcometerra.com')
# ('Compose AI', 'compose.ai')
# ('HyperWrite', 'hyperwriteai.com')
# ('Sudowrite', 'sudowrite.com')
# ('Oasis', 'theoasis.com')
# ('Replika', 'replika.ai')
# ('Chai', 'chai-research.com')
# ('QuickChat', 'quickchat.io')
# ('Soundful', 'soundful.com')
# ('Mubert', 'mubert.com')
# ('Boomy', 'boomy.com')
# ('Aimi', 'aimi.fm')
# ('Plask', 'plask.ai')
# ('DeepMotion', 'deepmotion.com')
# ('RADiCAL', 'radicalmotion.com')
# ('Craiyon', 'craiyon.com')
# ('Midjourney', 'midjourney.com')
# ('OpenAI', 'openai.com')
# ('Contextual AI', 'contextual.ai')
# ('Together AI', 'together.ai')
# ('Databricks', 'databricks.com')
# ('xAI', 'x.ai')
# ('Runa AI', 'runaai.com')
# ('Lamini', 'lamini.ai')
# ('Baseplate', 'baseplate.ai')
# ('Qtis AI', 'qtis.ai')
# ('Scale', 'scale.com')
# ('Fiddler AI', 'fiddler.ai')
# ('Lightning AI', 'lightning.ai')
# ('WhyLabs', 'whylabs.ai')
# ('MosaicML', 'mosaicml.com')
# ('Snorkel AI', 'snorkel.ai')
# ('LangChain', 'langchain.com')
# ('Fixie', 'fixie.ai')
# ('MindsDB', 'mindsdb.com')
# ('Portkey', 'portkey.ai')
# ('D-Matrix', 'd-matrix.ai')
# ('Gentrace', 'gentrace.ai')
# ('Gretel', 'gretel.ai')
# ('DataRobot', 'datarobot.com')
# ('Domino', 'dominodatalab.com')
# ('Clarifai', 'clarifai.com')
# ('H2O.ai', 'h2o.ai')
# ('BentoML', 'bentoml.com')
# ('Continual', 'continual.ai')
# ('Arthur', 'arthur.ai')
# ('Kobalt Labs', 'kobaltlabs.com')
# ('Neural Magic', 'neuralmagic.com')
# ('Wallaroo', 'wallaroo.ai')
# ('Arize', 'arize.com')
# ('TruEra', 'truera.com')
# ('Robust Intelligence', 'robustintelligence.com')
# ('Aporia', 'aporia.com')
# ('Evidently AI', 'evidentlyai.com')
# ('Censius', 'censius.ai')
# ('OctoML', 'octoml.ai')
# ('Modzy', 'modzy.com')
# ('Credo AI', 'credo.ai')
# ('MAIHEM', 'maihem.ai')
# ('Reducto AI', 'reducto.ai')
# ('Glaive', 'glaive.ai')
# ('Arcee', 'arcee.ai')
# ('Martian', 'withmartian.com')
# ('Cleanlab', 'cleanlab.ai')
# ('Automorphic', 'automorphic.ai')
# ('Taylor AI', 'trytaylor.ai')
# ('Deasie', 'deasie.com')
# ('LlamaIndex', 'llamaindex.ai')
# ('Talc', 'talc.ai')
# ('FiddleCube', 'fiddlecube.ai')
# ('Patronus AI', 'patronus.ai')
# ('DeepInfra', 'deepinfra.com')
# ('SID', 'sid.ai')
# ('VectorShift', 'vectorshift.ai')
# ('Unstructured', 'unstructured.io')
# ('Chatter', 'trychatter.ai')
# ('TextQL', 'textql.com')
# ('PromptLoop', 'promptloop.com')
# ('Baserun', 'baserun.ai')
# ('DAGWorks', 'dagworks.io')
# ('Panosight', 'panosight.ai')
# ('Vecflow', 'vecflow.ai')
# ('Guardrail ML', 'useguardrail.com')
# ('Confident AI', 'confident-ai.com')
# ('Hegel AI', 'hegel-ai.com')
# ('HydroX AI', 'hydrox.ai')
# ('Konko AI', 'konko.ai')
# ('Athina AI', 'athina.ai')
# ('Lega', 'lega.ai')
# ('Kore.ai', 'kore.ai')
# ('Abacus.AI', 'abacus.ai')
# ('Aible', 'aible.com')
# ('Numbers Station', 'numbersstation.ai')
# ('DataCebo', 'datacebo.com')
# ('Watchful', 'watchful.io')
# ('RagaAI', 'raga.ai')
# ('dottxt', 'dottxt.co')
# ('TieSet', 'tie-set.com')
# ('Trustwise', 'trustwise.ai')
# ('Monster API', 'monsterapi.ai')
# ('Carbon', 'carbon.ai')
# ('OpenPipe', 'openpipe.ai')
# ('Query Vary', 'queryvary.com')
# ('Shorthills AI', 'shorthills.ai')
# ('GradientJ', 'gradientj.com')
# ('Forefront', 'forefront.ai')
# ('Replicate', 'replicate.com')
# ('Calypso AI', 'calypsoai.com')
# ('HiddenLayer', 'hiddenlayer.com')
# ('Klleon', 'klleon.io')
# ('Tavus', 'tavus.io')
# ('Beam', 'beam.so')
# ('Nyx.gallery', 'nyx.gallery')
# ('mage.space', 'mage.space')
# ('OpenArt', 'openart.ai')
# ('Lexica', 'lexica.art')
# ('Booth AI', 'booth.ai')
# ('Hyperreal', 'hyperreal.io')
# ('Apriora', 'apriora.ai')
# ('Our Ability', 'ourability.com')
# ('Vizcom', 'vizcom.ai')
# ('Aragon', 'aragon.ai')
# ('Mirage', 'mirageml.com')
# ('Poly', 'withpoly.com')
# ('Diagram', 'withdiagram.com')
# ('Etched', 'etched.ai')
# ('Lumona', 'lumona.ai')
# ('Perplexity AI', 'perplexity.ai')
# ('Andi', 'andisearch.com')
# ('Vectara', 'vectara.com')
# ('Twelve Labs', 'twelvelabs.io')
# ('You.com', 'you.com')
# ('Neeva', 'neeva.com')
# ('Exa', 'exa.ai')
# ('EleutherAI', 'eleuther.ai')
# ('Pinscreen', 'pinscreen.com')
# ('HeyGen', 'heygen.com')
# ('UneeQ', 'digitalhumans.com')
# ('The AI Foundation', 'aifoundation.com')
# ('Rephrase.ai', 'rephrase.ai')
# ('D-ID', 'd-id.com')
# ('Pulze.ai', 'pulze.ai')
# ('Sublayer', 'sublayer.com')
# ('NuMind', 'numind.ai')
# ('Flip AI', 'flip.ai')
# ('Leo AI', 'getleo.ai')
# ('Autoblocks', 'autoblocks.ai')
# ('Galileo AI', 'usegalileo.ai')
# ('Nexusflow', 'nexusflow.ai')
# ('Jericho Security', 'jerichosecurity.com')
# ('Shiboleth', 'shiboleth.ai')
# ('Wraithwatch', 'wraithwatch.com')
# ('System Two Security', 'systemtwosecurity.com')
# ('Cape Privacy', 'capeprivacy.com')
# ('Reken', 'reken.ai')
# ('Sec3', 'sec3.dev')
# ('Inkeep AI', 'inkeep.com')
# ('Uniphore', 'uniphore.com')
# ('Forethought', 'forethought.ai')
# ('Sapling Intelligence', 'sapling.ai')
# ('Verneek', 'verneek.com')
# ('Quickchat AI', 'quickchat.ai')
# ('Thankful', 'thankful.ai')
# ('NLX', 'nlx.ai')
# ('Gleen', 'gleen.ai')
# ('Markprompt', 'markprompt.com')
# ('Toma', 'toma.so')
# ('Centralize', 'usecentralize.com')
# ('HiOperator', 'hioperator.com')
# ('Alltius', 'alltius.ai')
# ('VAO Labs', 'vao.world')
# ('Monterey', 'monterey.ai')
# ('Humane', 'humane.com')
# ('Rewind', 'rewind.ai')
# ('Tab', 'mytab.ai')
# ('rabbit', 'rabbit.tech')
# ('Reface', 'hey.reface.ai')
# ('Maia', 'ourmaia.com')
# ('Alai', 'getalai.com')
# ('Personal AI', 'personal.ai')
# ('Earkick', 'earkick.com')
# ('Warp', 'warp.dev')
# ('Fig', 'fig.io')
# ('Cosine', 'cosine.sh')
# ('Mintlify', 'mintlify.com')
# ('Denigma Alpha', 'denigma.app')
# ('Replit', 'replit.com')
# ('MutableAI', 'mutable.ai')
# ('CodeComplete', 'codecomplete.ai')
# ('Second', 'second.dev')
# ('Codiga', 'codiga.io')
# ('Kite', 'kite.com')
# ('Deepgram', 'deepgram.com')
# ('Symbl.ai', 'symbl.ai')
# ('AssemblyAI', 'assemblyai.com')
# ('Cogram', 'cogram.com')
# ('Talka', 'talka.ai')
# ('Vocal Clarity', 'vocalclarity.ai')
# ('Griptape', 'griptape.ai')
# ('Imbue', 'imbue.com')
# ('Inflection', 'inflection.ai')
# ('Character.AI', 'beta.character.ai')
# ('Digi', 'digi.ai')
# ('Anthropic', 'anthropic.com')
# ('Adept', 'adept.ai')
# ('Superagent', 'superagent.sh')
